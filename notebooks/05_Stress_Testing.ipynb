# %% [markdown]
# # Credit Risk Analysis: Phase 5 - Stress Testing & Portfolio Risk Analytics
#
# **Objective**: Apply macro stress scenarios to shift PD, compute Expected Loss by sector, and generate risk visualizations.
#
# **Outputs**: EL waterfall, bubble chart, sector heatmap, and stressed vintage curves
#
# ---

# %% [markdown]
# ## 1. Import Libraries & Setup

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sys.path.insert(0, str(Path.cwd().parent / 'src'))

from stress_testing import StressTester

print("✅ Libraries imported")
# Out:
# ✅ Libraries imported

# %% [markdown]
# ## 2. Load Input Data

# %% [markdown]
# ## 3. Initialize Stress Tester

# %% [markdown]
# ## 4. Execute Full Stress Testing Pipeline

# %% [markdown]
# ## 5. Display EL by Sector Chart

# %% [markdown]
# ## 6. Display EL Waterfall Chart

# %% [markdown]
# ## 7. Display Sector Risk Bubble Chart

# %% [markdown]
# ## 8. Display EL Heatmap

# %% [markdown]
# ## 9. Summary & Next Steps
